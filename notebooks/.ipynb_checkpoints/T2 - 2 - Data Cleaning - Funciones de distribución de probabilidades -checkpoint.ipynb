# %% [markdown]
# # Funciones de distribución de probabilidades
# ## Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n = 1000000
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline 
plt.hist(data)

# %% [markdown]
# ## Distribución Normal

# %%
data = np.random.randn(1000000)

# %%
x = range(1,1000001)
plt.plot(x, data)

# %%
# %matplotlib inline
plt.hist(data)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(1000)
plt.hist(data)

# %% [markdown]
# ## La simulación de Monte Carlo

# %% [markdown]
# #### - Generamos dos números aleatorios x e y entre 0 y 1 en total 1000 veces
#
# #### - Calcularemos x^2 + y^2
#     * Si el valor es inferior a 1 -> estamos dentro del circulo.
#     * Si el valor es superior a 1 -> estamos fuera del circulo.
# #### - Calculamos el número total de veces que están dentro del círculo y lo dividimos entre el número total de     intentos para obtener una aproximación de la probabilidad de caer dentro del círculo.
#
# #### - Usamos dicha probabilidad para aproximar el valor de pi.
#
# #### - Repetimos el experimento un número suficiente de veces (por ejemplo 100), para obtener (100) diferentes aproximaciones de pi.
#
# #### - Calculamos el promedio de los 100 experimentos anteriores para dar un valor final de pi.

# %%
pi_avg = 0
n = 10000
pi_value_list = []
for i in range(100):
    value = 0 
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for j in range(n):
        z = np.sqrt(x[j]**2 + y[j]**2)
        if z<=1:
            value += 1
    float_value = float(value)
    pi_value = float_value * 4 / n
    pi_value_list.append(pi_value)
    pi_avg += pi_value
    
pi = pi_avg/100
print(pi)
plt.plot(pi_value_list)
# Out:
# 3.1410599999999995

# %% [markdown]
# ## Dummy Data Sets

# %%
n=1000000
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5 * np.random.randn(n),
        'C' : np.random.uniform(5, 32, n),
    }
)

# %%
data
# Out:
#                A         B          C
# 0      -0.195748  1.043434  13.705723
# 1       1.059908 -0.669547  20.102608
# 2       0.282772  3.089134  26.932887
# 3      -0.205570  3.316754  22.021514
# 4       0.154749  1.967400  18.824554
# ...          ...       ...        ...
# 999995  0.025644  2.882327  16.344838
# 999996 -0.908048  1.168826  22.125264
# 999997 -0.998460 -0.078279  31.597483
# 999998 -1.292684  3.570603  14.499433
# 999999 -0.195599  1.975869   5.620795
#
# [1000000 rows x 3 columns]

# %%
data.describe()
# Out:
#                     A               B               C
# count  1000000.000000  1000000.000000  1000000.000000
# mean         0.000079        1.497459       18.510446
# std          1.001471        2.500053        7.793637
# min         -5.068785      -10.425175        5.000016
# 25%         -0.674709       -0.188757       11.765631
# 50%         -0.000791        1.496424       18.508873
# 75%          0.674933        3.182859       25.263478
# max          4.835525       13.686189       31.999962

# %%
plt.hist(data["A"])
# Out:
# (array([2.30000e+01, 1.05300e+03, 1.69360e+04, 1.16422e+05, 3.19470e+05,
#         3.54421e+05, 1.60357e+05, 2.90500e+04, 2.21700e+03, 5.10000e+01]),
#  array([-5.06878506, -4.07835407, -3.08792309, -2.09749211, -1.10706112,
#         -0.11663014,  0.87380084,  1.86423183,  2.85466281,  3.84509379,
#          4.83552478]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["B"])
# Out:
# (array([5.20000e+01, 2.19400e+03, 2.80850e+04, 1.50711e+05, 3.40605e+05,
#         3.23803e+05, 1.30848e+05, 2.20500e+04, 1.59800e+03, 5.40000e+01]),
#  array([-10.42517474,  -8.01403838,  -5.60290202,  -3.19176565,
#          -0.78062929,   1.63050707,   4.04164343,   6.45277979,
#           8.86391615,  11.27505251,  13.68618887]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["C"])
# Out:
# (array([ 99586., 100111.,  99813.,  99982., 100211., 100083., 100032.,
#          99597.,  99945., 100640.]),
#  array([ 5.00001629,  7.7000109 , 10.40000551, 13.10000012, 15.79999473,
#         18.49998934, 21.19998395, 23.89997856, 26.59997317, 29.29996778,
#         31.99996239]),
#  <BarContainer object of 10 artists>)

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
columm_names = data.columns.values.tolist()

# %%
a = len(columm_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name' : columm_names,
        'A' : np.random.randn(a),
        'B' : np.random.uniform(0,1,a)
    }, index = range(42, 42 + a)
)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State -0.469067  0.255715
# 43  Account Length  0.762869  0.621898
# 44       Area Code  1.886314  0.239308
# 45           Phone -0.028178  0.002622
# 46      Int'l Plan -2.061642  0.549267
# 47      VMail Plan  0.831729  0.302149
# 48   VMail Message -0.504291  0.116412
# 49        Day Mins  1.063396  0.238822
# 50       Day Calls  0.643749  0.246368
# 51      Day Charge  1.696447  0.901252
# 52        Eve Mins  0.114573  0.943780
# 53       Eve Calls -0.388722  0.745666
# 54      Eve Charge  0.399023  0.335386
# 55      Night Mins  0.514464  0.711390
# 56     Night Calls  1.338122  0.330158
# 57    Night Charge  0.340834  0.532398
# 58       Intl Mins  0.270468  0.634697
# 59      Intl Calls -0.735617  0.003084
# 60     Intl Charge  0.210677  0.821738
# 61  CustServ Calls -1.951187  0.211287
# 62          Churn?  0.829678  0.948119
